# %% [markdown]
# # NBA Score Predictor
#
# ### Introduction
# Many individuals enjoy watching sport games. For some, it is more fun to predict the outcomes of teams. Based on elo and cameron measurements, can game scores be predicted for certain team matchups?

# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing
import matplotlib.pyplot as plt


#Import datasets
NBAgames=pd.read_csv('../data/external/nba_elo.csv')

# %% [markdown]
# ## Cleaning Data
#
# #### Rows
# Need to remove rows not containing carmelo scores. This reduces the timeframe from 2015-2018.
#
# #### Columns
# Neutral does not make sense in this context as it contains many zeroes. This is dropped. Furthermore, viewing playoff, many empty values exist, so this is also dropped. Lastly, viewing date and season does not make much sense as these do not necessarily determine data. Teams change over time with different players. These alterations are shown in elo and carmelo measurements as after each game, the numbers are changed.

# %%
#Dropping rows
NBAgames=NBAgames.dropna(subset=['carmelo1_pre'])

#Dropping columns
NBAgames=NBAgames.drop(columns=['neutral', 'playoff', 'date', 'season'])

# %% [markdown]
# ## Transformation
#
# After dropping unneccesary and unhelpful rows and columns,

# %%
NBAgames
# Out:
#              date  season team1 team2     elo1_pre     elo2_pre  elo_prob1  \
# 63157  2015-10-27    2016   CHI   CLE  1569.533975  1645.314425   0.534798
# 63158  2015-10-27    2016   ATL   DET  1561.843550  1472.058800   0.748850
# 63159  2015-10-27    2016   GSW   NOP  1742.966075  1521.178175   0.864404
# 63160  2015-10-28    2016   ORL   WAS  1360.168625  1535.828375   0.392806
# 63161  2015-10-28    2016   BRK   CHI  1469.552900  1573.944108   0.493681
# 63162  2015-10-28    2016   MIA   CHO  1468.145075  1426.797875   0.692889
# 63163  2015-10-28    2016   DET   UTA  1492.605998  1542.714050   0.571311
# 63164  2015-10-28    2016   TOR   IND  1501.545425  1504.903475   0.635600
# 63165  2015-10-28    2016   BOS   PHI  1519.678625  1333.391825   0.838620
# 63166  2015-10-28    2016   MEM   CLE  1582.509125  1640.904292   0.559590
# 63167  2015-10-28    2016   OKC   SAS  1563.671375  1666.972550   0.495249
# ...
